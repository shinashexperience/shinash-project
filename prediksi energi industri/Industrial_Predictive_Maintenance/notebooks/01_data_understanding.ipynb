# %% [markdown]
# # FASE 1 — Data Understanding
# ## Industrial Energy Monitoring & Predictive Maintenance
# **PT Nusantara Manufacturing | 2025**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-darkgrid')
print('Libraries loaded!')

# %%
df = pd.read_csv('../data/raw_data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
print(f'Dataset shape: {df.shape}')
print(f'Columns: {df.columns.tolist()}')
df.head(10)

# %%
print('=== DATA TYPES ===')
print(df.dtypes)
print()
print('=== MISSING VALUES ===')
print(df.isnull().sum())
print()
print('=== DUPLICATES ===')
print(f'Duplicate rows: {df.duplicated().sum()}')

# %%
print('=== STATISTICAL SUMMARY ===')
df.describe().round(3)

# %%
print('=== MACHINE IDs ===')
print(df['machine_id'].value_counts())
print()
print('=== STATUS DISTRIBUTION ===')
print(df['status'].value_counts())
print(f'Status ratio: {(df["status"]=="WARNING").mean()*100:.2f}% WARNING')

# %%
print(f'Date range: {df["timestamp"].min()} to {df["timestamp"].max()}')
print(f'Total hours: {len(df["timestamp"].unique())}')
print(f'Records per machine: {df.groupby("machine_id").size().to_dict()}')

# %% [markdown]
# ## Data Dictionary
#
# | Kolom | Tipe | Satuan | Arti |
# |-------|------|--------|------|
# | timestamp | datetime | — | Waktu pencatatan |
# | machine_id | string | — | ID Mesin |
# | voltage_v | float | Volt | Tegangan listrik |
# | current_a | float | Ampere | Arus listrik |
# | power_kw | float | kW | Daya aktif |
# | temperature_c | float | °C | Suhu operasional |
# | vibration_mm_s | float | mm/s | Vibrasi |
# | power_factor | float | — | Faktor daya |
# | status | string | — | Status mesin |
